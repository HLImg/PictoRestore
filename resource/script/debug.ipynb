# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://icvl.cs.bgu.ac.il/hyperspectral/"
response = requests.get(url)

soup = BeautifulSoup(response.text, 'html.parser')

# %%
file = {}
for hs_box in soup.find_all('div', class_='hs_box'):
    file_name = hs_box.find('h4', class_='hs_title').text
    
    for a_tag in hs_box.find('div', class_='hs-files').find_all('a'):
        ext = a_tag.text.strip()
        if ext == '.mat':
            file[file_name] = a_tag['href']
            break

# %%
len(file)

from tqdm import tqdm

# %%
for _, hs_box in enumerate(tqdm(soup.find_all('div', class_='hs_box'))):
    file_name = hs_box.find('h4', class_='hs_title').text
    print(file_name)
# Out:
# 100%|██████████| 201/201 [00:00<00:00, 20365.13it/s]
# 4cam_0411-1640-1
# 4cam_0411-1648
# bguCAMP_0514-1659
# bguCAMP_0514-1711
# bguCAMP_0514-1712
# bguCAMP_0514-1718
# bguCAMP_0514-1723
# bguCAMP_0514-1724
# BGU_0403-1419-1
# bgu_0403-1439
# bgu_0403-1444
# bgu_0403-1459
# bgu_0403-1511
# bgu_0403-1523
# bgu_0403-1525
# BGU_0522-1113-1
# BGU_0522-1127
# BGU_0522-1136
# BGU_0522-1201
# BGU_0522-1203
# BGU_0522-1211
# BGU_0522-1216
# BGU_0522-1217
# bulb_0822-0903
# bulb_0822-0909
# CC_40D_2_1103-0917
# eve_0331-1549
# eve_0331-1551
# eve_0331-1601
# eve_0331-1602
# eve_0331-1606
# eve_0331-1618
# eve_0331-1632
# eve_0331-1633
# eve_0331-1646
# eve_0331-1647
# eve_0331-1656
# eve_0331-1657
# eve_0331-1702
# eve_0331-1705
# Flower_0325-1336
# gavyam_0823-0930
# gavyam_0823-0933
# gavyam_0823-0944
# gavyam_0823-0945
# gavyam_0823-0950-1
# grf_0328-0949
# hill_0325-1219
# hill_0325-1228
# hill_0325-1235
# hill_0325-1242
# IDS_COLORCHECK_1020-1215-1
# IDS_COLORCHECK_1020-1223
# Labtest_0910-1502
# Labtest_0910-1504
# Labtest_0910-1506
# Labtest_0910-1509
# Labtest_0910-1510
# Labtest_0910-1511
# Labtest_0910-1513
# lehavim_0910-1600
# lehavim_0910-1602
# lehavim_0910-1605
# lehavim_0910-1607
# lehavim_0910-1610
# Lehavim_0910-1622
# Lehavim_0910-1626
# Lehavim_0910-1627
# Lehavim_0910-1629
# Lehavim_0910-1630
# Lehavim_0910-1633
# Lehavim_0910-1635
# Lehavim_0910-1636
# Lehavim_0910-1640
# Lehavim_0910-1708
# Lehavim_0910-1716
# Lehavim_0910-1717
# Lehavim_0910-1718
# Lehavim_0910-1725
# lst_0408-0950
# lst_0408-1004
